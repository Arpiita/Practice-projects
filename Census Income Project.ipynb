# %%
#importing libraries
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from scipy.stats import zscore
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import cross_val_score
import joblib
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education_num   32560.0      10.080590       2.572709      1.0       9.0
# Capital_gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# Hours_per_week  32560.0      40.437469      12.347618      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education_num       10.0      12.0       16.0
# Capital_gain         0.0       0.0    99999.0
# Capital_loss         0.0       0.0     4356.0
# Hours_per_week      40.0      45.0       99.0

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
#Checking unique values of each column
df.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %% [markdown]
# There are unique values in every columns

# %%
#Checking null values in the dataset
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# No null values found

# %%
#Visualizeing null values
plt.figure(figsize=[10,4])
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %%
#Checking unique values of target column
df['Income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %% [markdown]
# Only two unique counts in the target column so it's a binary classification problem.

# %%
#Lets check the value count of each column to see if there are any unexpected and unwanted entries present in the column.
for i in df.columns:
        print(df[i].value_counts())
        print('****************************************')
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
# ****************************************
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# ****************************************
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64
# ****************************************
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64
# ****************************************
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: Education_num, dtype: int64
# ****************************************
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64
# ****************************************
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64
# ****************************************
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64
# ****************************************
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64
# ****************************************
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64
# ****************************************
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: Capital_gain, Length: 119, dtype: int64
# ****************************************
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: Capital_loss, Length: 92, dtype: int64
# ****************************************
# 40    15216
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 82        1
# 94        1
# 92        1
# 74        1
# 87        1
# Name: Hours_per_week, Length: 94, dtype: int64
# ****************************************
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64
# ****************************************
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64
# ****************************************

# %% [markdown]
# There are '?' entries in Workclass, Occupation and Native_country column. Since they are categorical columns we will replace it by using Mode.

# %%
# let's check the mode of Workclass column 
df["Workclass"].mode()  # we will fill the '?' values with this mode value
# Out:
# 0     Private
# Name: Workclass, dtype: object

# %%
#Replacing '?' with mode value
df['Workclass'] = df.Workclass.str.replace('?', 'Private')

# %%
# let's check the mode of Occupation column 
df["Occupation"].mode()
# Out:
# 0     Prof-specialty
# Name: Occupation, dtype: object

# %%
#Replacing '?' with mode value
df['Occupation'] = df.Occupation.str.replace('?', 'Prof-specialty')

# %%
# let's check the mode of Native_country column 
df["Native_country"].mode()
# Out:
# 0     United-States
# Name: Native_country, dtype: object

# %%
#Replacing '?' with mode value
df['Native_country'] = df.Native_country.str.replace('?', 'United-States')

# %%
#Checking the value count of Capital_gain column
df["Capital_gain"].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: Capital_gain, Length: 119, dtype: int64

# %% [markdown]
# In Capital_gain column there are 92% zero values so dropping this column.

# %%
#Droping Capital_gain column
df = df.drop(["Capital_gain"],axis=1)

# %%
#Checking the value count of Capital_loss column
df["Capital_loss"].value_counts()
# Out:
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: Capital_loss, Length: 92, dtype: int64

# %% [markdown]
# In Capital_loss column there are 95% zero values so let's drop this column also

# %%
#Droping Capital_loss column
df = df.drop(["Capital_loss"],axis=1)

# %%
#Checking data set
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Hours_per_week
# count  32560.000000  3.256000e+04   32560.000000    32560.000000
# mean      38.581634  1.897818e+05      10.080590       40.437469
# std       13.640642  1.055498e+05       2.572709       12.347618
# min       17.000000  1.228500e+04       1.000000        1.000000
# 25%       28.000000  1.178315e+05       9.000000       40.000000
# 50%       37.000000  1.783630e+05      10.000000       40.000000
# 75%       48.000000  2.370545e+05      12.000000       45.000000
# max       90.000000  1.484705e+06      16.000000       99.000000

# %% [markdown]
# # Data Visualization

# %%
# Separating categorical columns
categorical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_columns.append(i)
print(categorical_columns)
# Out:
# ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
# Separating numerical columns
numerical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_columns.append(i)
print(numerical_columns)
# Out:
# ['Age', 'Fnlwgt', 'Education_num', 'Hours_per_week']

# %% [markdown]
# # UniVariate Analysis

# %%
#Distribution plot for all numerical columns
for i in df[numerical_columns]:              
    plt.figure(figsize = (8, 4))
    sns.distplot(df[i], bins = 10, color="g")
    plt.title(i)
    plt.show()

# %%
#Count plot for Income
sns.countplot(df['Income']);

# %% [markdown]
# From above we can see that the data is imbalance and most of the people are getting income below 50k per year.

# %%
#Count plot for Workclass
sns.countplot(df['Workclass'])
plt.xticks(rotation=90);

# %% [markdown]
# We can see that most of the people are working in Private Sector

# %%
#Count plot for Education_num
sns.countplot(df['Education_num'])
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='count'>

# %% [markdown]
# Maximum workers belong to Education number 9,10,13 and very less people belong to 1,2,3.

# %%
#Count plot for Education
sns.countplot(df['Education'])
plt.xticks(rotation=90);

# %% [markdown]
# Above plot says that HS-grad, Bachelors and Some-college has maximum count

# %%
#Count plot for Marital_status
sns.countplot(df['Marital_status'])
plt.xticks(rotation=90);

# %% [markdown]
# People who are Married-civ-spouse, Never-married are more in number

# %%
#Hist plot for Occupation
sns.histplot(df['Occupation'],color='salmon')
plt.xticks(rotation=90);

# %% [markdown]
# Most of the people has choosen Prof-specialty,Exec-managerial, Craft-repair as there Occupation

# %%
#Checking the value count of Relationship column
df["Relationship"].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
#Ploting pie chart for Relationship
labels='Husband','Not-in-family','Own-child','Unmarried','Wife','Other-relative'
fig, ax = plt.subplots()
ax.pie(df['Relationship'].value_counts(), labels=labels, autopct='%1.2f%%', shadow=True)
plt.show()

# %%
#Factor plot for Race
sns.factorplot('Race',kind='count',data=df,hue='Income')
plt.xticks(rotation=90);

# %%
#Factor plot for Sex
sns.factorplot('Sex',kind='count',data=df,hue='Income')
plt.xticks(rotation=0);

# %%
#Checking the value count of Sex column
df["Sex"].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
#Ploting pie chart for Sex
labels='Male','Female'
fig, ax = plt.subplots()
ax.pie(df['Sex'].value_counts(), labels=labels, autopct='%1.2f%%', shadow=True)
plt.show()

# %%
#Hist plot for Native_country
plt.figure(figsize=[15,10])
sns.histplot(df['Native_country'],color='salmon')
plt.xticks(rotation=90);

# %% [markdown]
# # Observation-
# -  By looking at the pie chart we see most of the count are with Husband.
# -  In US white people have more chances of getting job.
# -  Irrespective of income males have high count of getting job than women.And men also have high count of getting income >50k per year.
# -  We can see that most of the working people about 67% are male rest are female.
# -  Most of the people in US are working.

# %% [markdown]
# # Bivariate Analysis:

# %%
# Let's plot catplot for Workclass and Age
sns.catplot(x = "Workclass", y = "Age", hue = "Income", kind = "violin", data=df, split=True,palette='Set2')
plt.xticks(rotation=90);

# %%
# Let's plot catplot for Marital_status and Education_num
sns.catplot(x = "Marital_status", y = "Education_num", hue = "Income", kind = "violin", data=df, split=True)
plt.xticks(rotation=90);

# %%
# Let's plot catplot for Sex and Fnlwgt
sns.catplot(x = "Sex", y = "Fnlwgt", hue = "Income", kind = "violin", data=df, split=True)
plt.xticks(rotation=90);

# %%
# Let's plot catplot for Race and Age
sns.catplot(x = "Race", y = "Age", hue = "Income", kind = "violin", data=df, split=True)
plt.xticks(rotation=90);

# %%
#Comparision between features using scatter plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Age and Fnlwgt')
sns.scatterplot(df['Age'],df['Fnlwgt'],hue=df["Income"]);

# %%
#Comparision between features using scatter plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Education_num and Age')
sns.scatterplot(df['Education_num'],df['Age'],hue=df["Income"]);

# %% [markdown]
# # Observation
# -  All the Workclass has chance of getting income >50k except Without-pay and Never-worked.Which means if a person is working then there is a chance that he gets income of >50k.But if he is not at all working then obviously he'll not get that much  income.
# -  If the education number is high then obviously Income is high, but for married-spouse-absent it is showing high education_num.
# -  Both for male and female the Fnlwgt is same and they have same income also.
# -  Chances of getting income >50k is more in case of Whites.That means in US white people are prefered.
# -  As the age of the worker increses there is less chance to get more income,And also as the Fnlgwt increases then the chance to get income is decreaseing.
# -  People with age above 70 has less chances of getting work and As the education number increases then the chance of getting income>50k is also high.

# %%
fig,axes=plt.subplots(2,2,figsize=(12,10))

# Checking income with Fnlwgt
sns.barplot(x='Income',y='Fnlwgt',ax=axes[0,0],data=df,palette='ch:.25')

# Checking income with Capital_gain
sns.barplot(x='Income',y='Age',ax=axes[0,1],data=df,palette='Set2')

# Checking income with Capital_loss
sns.barplot(x='Income',y='Education_num',ax=axes[1,0],data=df,palette='Set2')

# Checking income with Hours_per_week
sns.barplot(x='Income',y='Hours_per_week',ax=axes[1,1],data=df,palette='ch:.25')
plt.show()

# %% [markdown]
# -  With Fnlwgt the chances of getting income >50k and <=50k both are almost equal.
# -  With Age the chance of getting >50k is high compared to getting income <=50k.
# -  With Education_num the chance of getting income >50k is very high than <=50k.
# -  With hours_per_week also the chance of getting income >50k is high

# %%
#Comparision between features using line plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Age and Education_num')
sns.lineplot(df['Age'],df['Education_num'],hue=df["Income"]);

# %% [markdown]
# We can see as the education number is increasing the chance of getting income >5ok is also increasing.In same way as the age increases means more the experience more is the chance of getting income more than 50k.

# %% [markdown]
# # Multivariate Analysis:

# %%
#pair ploting for df
sns.pairplot(df,hue="Income")

# %% [markdown]
# We can see outliers and skewness in the dataset from the above plot

# %% [markdown]
# # Checking Outliers:

# %%
#Using boxplot
df.plot(rot = 90,kind='box',fontsize=14,figsize=(25,25),color='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are outliers in all the numerical columns

# %% [markdown]
# # Removing Outliers

# %%
dfoutliers=df[["Age","Fnlwgt","Education_num","Hours_per_week"]]

# %%
#Using Zscore method
z=np.abs(zscore(dfoutliers))
df_new=df[(z<3).all(axis=1)]
df_new.head(5)
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# 1              40   United-States   <=50K
# 2              40   United-States   <=50K
# 3              40            Cuba   <=50K
# 4              40   United-States   <=50K

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (31461, 13)

# %%
#Checking dataloss in zscore method
Dataloss=(((32560-31461)/32560)*100)
Dataloss
# Out:
# 3.3753071253071254

# %% [markdown]
# # Checking for skewness

# %%
df_new.skew()
# Out:
# Age               0.472279
# Fnlwgt            0.634828
# Education_num    -0.159752
# Hours_per_week   -0.341724
# dtype: float64

# %%
#Removing skewness using yeo-johnson method:

fea=["Fnlwgt"]

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %%
df_new[fea] = scaler.fit_transform(df_new[fea].values)

# %%
#Checking skewness again
df_new[fea].skew()
# Out:
# Fnlwgt   -0.034507
# dtype: float64

# %% [markdown]
# Skewness is removed.

# %%
#Checking distplot for skewed columns after removing skewness
sns.distplot(df_new[fea],color='g')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Label Encoding
# Separating categorical columns in df_new
cat_col=[]
for i in df_new.dtypes.index:
    if df_new.dtypes[i]=='object':
        cat_col.append(i)
print(cat_col)
# Out:
# ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
LE=LabelEncoder()
df_new[cat_col]= df_new[cat_col].apply(LE.fit_transform)

# %%
df_new[cat_col].head()
# Out:
#    Workclass  Education  Marital_status  Occupation  Relationship  Race  Sex  \
# 0          5          8               2           3             0     4    1
# 1          3         10               0           5             1     4    1
# 2          3          1               2           5             0     2    1
# 3          3          8               2           9             5     2    0
# 4          3         11               2           3             5     4    0
#
#    Native_country  Income
# 0              38       0
# 1              38       0
# 2              38       0
# 3               4       0
# 4              38       0

# %%
df_new.head()
# Out:
#    Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          5 -1.114171          8             13               2
# 1   38          3  0.427192         10              9               0
# 2   53          3  0.607320          1              7               2
# 3   28          3  1.487719          8             13               2
# 4   37          3  1.048962         11             14               2
#
#    Occupation  Relationship  Race  Sex  Hours_per_week  Native_country  Income
# 0           3             0     4    1              13              38       0
# 1           5             1     4    1              40              38       0
# 2           5             0     2    1              40              38       0
# 3           9             5     2    0              40               4       0
# 4           3             5     4    0              40              38       0

# %% [markdown]
# # Checking Correlation

# %%
cor=df_new.corr()

# %%
cor
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.038024 -0.066519  -0.000447       0.053361
# Workclass       0.038024   1.000000 -0.021654   0.004652       0.003831
# Fnlwgt         -0.066519  -0.021654  1.000000  -0.024191      -0.033150
# Education      -0.000447   0.004652 -0.024191   1.000000       0.356040
# Education_num   0.053361   0.003831 -0.033150   0.356040       1.000000
# Marital_status -0.286424  -0.020597  0.027732  -0.039094      -0.065568
# Occupation     -0.001321   0.007551  0.001992  -0.041224       0.073927
# Relationship   -0.268028  -0.056825  0.008287  -0.015121      -0.102497
# Race            0.030679   0.046295 -0.008299   0.015552       0.030849
# Sex             0.091664   0.070095  0.025290  -0.024911       0.016662
# Hours_per_week  0.097510   0.030311 -0.015566   0.061325       0.160483
# Native_country -0.001039  -0.001602 -0.061214   0.068374       0.054510
# Income          0.248351   0.003494 -0.004586   0.077526       0.337595
#
#                 Marital_status  Occupation  Relationship      Race       Sex  \
# Age                  -0.286424   -0.001321     -0.268028  0.030679  0.091664
# Workclass            -0.020597    0.007551     -0.056825  0.046295  0.070095
# Fnlwgt                0.027732    0.001992      0.008287 -0.008299  0.025290
# Education            -0.039094   -0.041224     -0.015121  0.015552 -0.024911
# Education_num        -0.065568    0.073927     -0.102497  0.030849  0.016662
# Marital_status        1.000000    0.034640      0.185772 -0.067546 -0.127375
# Occupation            0.034640    1.000000     -0.037549 -0.004094  0.047864
# Relationship          0.185772   -0.037549      1.000000 -0.115216 -0.582940
# Race                 -0.067546   -0.004094     -0.115216  1.000000  0.088642
# Sex                  -0.127375    0.047864     -0.582940  0.088642  1.000000
# Hours_per_week       -0.197532   -0.019943     -0.263412  0.045331  0.239039
# Native_country       -0.017606   -0.003666     -0.010871  0.122051  0.002060
# Income               -0.198475    0.034612     -0.251506  0.072451  0.216665
#
#                 Hours_per_week  Native_country    Income
# Age                   0.097510       -0.001039  0.248351
# Workclass             0.030311       -0.001602  0.003494
# Fnlwgt               -0.015566       -0.061214 -0.004586
# Education             0.061325        0.068374  0.077526
# Education_num         0.160483        0.054510  0.337595
# Marital_status       -0.197532       -0.017606 -0.198475
# Occupation           -0.019943       -0.003666  0.034612
# Relationship         -0.263412       -0.010871 -0.251506
# Race                  0.045331        0.122051  0.072451
# Sex                   0.239039        0.002060  0.216665
# Hours_per_week        1.000000        0.004413  0.242383
# Native_country        0.004413        1.000000  0.017698
# Income                0.242383        0.017698  1.000000

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(20,15))
sns.heatmap(df_new.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g', annot = True, linecolor="black",annot_kws={'size':10},cmap="coolwarm")
plt.yticks(rotation=0);

# %% [markdown]
# -  By looking into the heat map we can see that there is no multicolinearity issue.
# -  Workclass and Fnlwgt has very less correlation with target column.
# -  Native_country, Occupation, Race and Education has less correlation with target column.

# %%
plt.figure(figsize=(20,10))
df_new.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Workclass and Fnlwgt are very less correlated to Target column.

# %%
#Droping less correlated column
df_new = df_new.drop(["Workclass"],axis=1)

# %% [markdown]
# # Separeting and Scaling the data

# %%
x = df_new.drop("Income",axis=1)
y = df_new["Income"]

# %%
# Using Standard Scaler
scaler=StandardScaler()
X = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#         Age    Fnlwgt  Education  Education_num  Marital_status  Occupation  \
# 0  0.875057 -1.114171  -0.348344       1.154324       -0.403597   -0.784335
# 1 -0.025350  0.427192   0.245782      -0.459657       -1.733114   -0.282327
# 2  1.100158  0.607320  -2.427783      -1.266647       -0.403597   -0.282327
# 3 -0.775689  1.487719  -0.348344       1.154324       -0.403597    0.721690
# 4 -0.100384  1.048962   0.542845       1.557819       -0.403597   -0.784335
#
#    Relationship      Race       Sex  Hours_per_week  Native_country
# 0     -0.903178  0.391304  0.706601       -2.424121        0.254062
# 1     -0.281938  0.391304  0.706601       -0.008364        0.254062
# 2     -0.903178 -1.969806  0.706601       -0.008364        0.254062
# 3      2.203019 -1.969806 -1.415226       -0.008364       -5.457546
# 4      2.203019  0.391304 -1.415226       -0.008364        0.254062

# %% [markdown]
# # Balancing the target variable

# %%
#Checking the value count of target column
y.value_counts()
# Out:
# 0    23853
# 1     7608
# Name: Income, dtype: int64

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\arpita\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\arpita\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\arpita\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\arpita\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\arpita\anaconda3\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arpita\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import imblearn
from imblearn.over_sampling import SMOTE

# %%
# Checking the value counts again
y.value_counts()
# Out:
# 0    23853
# 1     7608
# Name: Income, dtype: int64

# %%
SM = SMOTE()
X, y = SM.fit_resample(X,y)

# %%
# Visualizing the data after oversampling
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# The data is fully balanced now.

# %% [markdown]
# # Finding Best Random State and Accuracy:

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.30, random_state =i)
    mod = RandomForestClassifier()
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [181], in <cell line: 3>()
#       4 X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.30, random_state =i)
#       5 mod = RandomForestClassifier()
# ----> 6 mod.fit(X_train, y_train)
#       7 pred = mod.predict(X_test)
#       8 acc=accuracy_score(y_test, pred)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:450, in BaseForest.fit(self, X, y, sample_weight)
#     439 trees = [
#     440     self._make_estimator(append=False, random_state=random_state)
#     441     for i in range(n_more_estimators)
#     442 ]
#     444 # Parallel loop: we prefer the threading backend as the Cython code
#     445 # for fitting the trees is internally releasing the Python GIL
#     446 # making threading more efficient than multiprocessing in
#     447 # that case. However, for joblib 0.12+ we respect any
#     448 # parallel_backend contexts set at a higher level,
#     449 # since correctness does not rely on using threads.
# --> 450 trees = Parallel(
#     451     n_jobs=self.n_jobs,
#     452     verbose=self.verbose,
#     453     **_joblib_parallel_args(prefer="threads"),
#     454 )(
#     455     delayed(_parallel_build_trees)(
#     456         t,
#     457         self,
#     458         X,
#     459         y,
#     460         sample_weight,
#     461         i,
#     462         len(trees),
#     463         verbose=self.verbose,
#     464         class_weight=self.class_weight,
#     465         n_samples_bootstrap=n_samples_bootstrap,
#     466     )
#     467     for i, t in enumerate(trees)
#     468 )
#     470 # Collect newly grown trees
#     471 self.estimators_.extend(trees)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in __call__(self, iterable)
#    1044     self._backend.start_call()
#    1045 iterator = iter(iterable)
# -> 1046 pre_dispatch = self.pre_dispatch
#    1048 if pre_dispatch == 'all' or n_jobs == 1:
#    1049     # prevent further dispatch via multiprocessing callback thread
#    1050     self._original_iterator = None
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in dispatch_one_batch(self, iterator)
#     852     batch_size = self.batch_size
#     854 with self._lock:
#     855     # to ensure an even distribution of the workolad between workers,
#     856     # we look ahead in the original iterators more than batch_size
#    (...)
#     859     # queue, _ready_batches, that is looked-up prior to re-consuming
#     860     # tasks from the origal iterator.
# --> 861     try:
#     862         tasks = self._ready_batches.get(block=False)
#     863     except queue.Empty:
#     864         # slice the iterator n_jobs * batchsize items at a time. If the
#     865         # slice returns less than that, then the current batchsize puts
#    (...)
#     868         # accordingly to distribute evenly the last items between all
#     869         # workers.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in _dispatch(self, batch)
#     775     n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
#     776                                      **self._backend_args)
#     777     if self.timeout is not None and not self._backend.supports_timeout:
#     778         warnings.warn(
# --> 779             'The backend class {!r} does not support timeout. '
#     780             "You have set 'timeout={}' in Parallel but "
#     781             "the 'timeout' parameter will not be used.".format(
#     782                 self._backend.__class__.__name__,
#     783                 self.timeout))
#     785 except FallbackToBackend as e:
#     786     # Recursively initialize the backend in case of requested fallback.
#     787     self._backend = e.backend
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in __init__(self, batch)
#     571 def terminate(self):
# --> 572     if self._workers is not None:
#     573         # Don't terminate the workers as we want to reuse them in later
#     574         # calls, but cleanup the temporary resources that the Parallel call
#     575         # created. This 'hack' requires a private, low-level operation.
#     576         self._workers._temp_folder_manager._unlink_temporary_resources(
#     577             context_id=self.parallel._id
#     578         )
#     579         self._workers = None
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in __call__(self)
#     256 # Under Linux or OS X the default start method of multiprocessing
#     257 # can cause third party libraries to crash. Under Python 3.4+ it is possible
#     258 # to set an environment variable to switch the default start method from
#     259 # 'fork' to 'forkserver' or 'spawn' to avoid this issue albeit at the cost
#     260 # of causing semantic changes and some additional pool instantiation overhead.
#     261 DEFAULT_MP_CONTEXT = None
# --> 262 if hasattr(mp, 'get_context'):
#     263     method = os.environ.get('JOBLIB_START_METHOD', '').strip() or None
#     264     if method is not None:
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     256 # Under Linux or OS X the default start method of multiprocessing
#     257 # can cause third party libraries to crash. Under Python 3.4+ it is possible
#     258 # to set an environment variable to switch the default start method from
#     259 # 'fork' to 'forkserver' or 'spawn' to avoid this issue albeit at the cost
#     260 # of causing semantic changes and some additional pool instantiation overhead.
#     261 DEFAULT_MP_CONTEXT = None
# --> 262 if hasattr(mp, 'get_context'):
#     263     method = os.environ.get('JOBLIB_START_METHOD', '').strip() or None
#     264     if method is not None:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:172, in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     169 else:
#     170     curr_sample_weight = sample_weight.copy()
# --> 172 indices = _generate_sample_indices(
#     173     tree.random_state, n_samples, n_samples_bootstrap
#     174 )
#     175 sample_counts = np.bincount(indices, minlength=n_samples)
#     176 curr_sample_weight *= sample_counts
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:129, in _generate_sample_indices(random_state, n_samples, n_samples_bootstrap)
#     125 """
#     126 Private function used to _parallel_build_trees function."""
#     128 random_instance = check_random_state(random_state)
# --> 129 sample_indices = random_instance.randint(0, n_samples, n_samples_bootstrap)
#     131 return sample_indices
#
# KeyboardInterrupt:

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# # Best Model Selection

# %%
#Using Decision Tree Classifier
DTC=DecisionTreeClassifier()
DTC.fit(X_train,y_train)
preddt=DTC.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, preddt))
print('Confusion Matrix:',confusion_matrix(y_test, preddt))
print(classification_report(y_test,preddt))
# Out:
# Accuracy Score: 0.8288848518725545
# Confusion Matrix: [[5925 1247]
#  [1202 5938]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      7172
#            1       0.83      0.83      0.83      7140
#
#     accuracy                           0.83     14312
#    macro avg       0.83      0.83      0.83     14312
# weighted avg       0.83      0.83      0.83     14312

# %%
#Using Random Forest Classifier
RFC=RandomForestClassifier()
RFC.fit(X_train,y_train)
predrf=RFC.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, predrf))
print('Confusion Matrix:',confusion_matrix(y_test, predrf))
print(classification_report(y_test,predrf))
# Out:
# Accuracy Score: 0.882406372275014
# Confusion Matrix: [[6193  979]
#  [ 704 6436]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88      7172
#            1       0.87      0.90      0.88      7140
#
#     accuracy                           0.88     14312
#    macro avg       0.88      0.88      0.88     14312
# weighted avg       0.88      0.88      0.88     14312

# %%
#Using SVC
SV=SVC()
SV.fit(X_train,y_train)
predsv=SV.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, predsv))
print('Confusion Matrix:',confusion_matrix(y_test, predsv))
print(classification_report(y_test,predsv))
# Out:
# Accuracy Score: 0.8167970933482392
# Confusion Matrix: [[5403 1769]
#  [ 853 6287]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80      7172
#            1       0.78      0.88      0.83      7140
#
#     accuracy                           0.82     14312
#    macro avg       0.82      0.82      0.82     14312
# weighted avg       0.82      0.82      0.82     14312

# %%
# USing KNN
knn=KNN()
knn.fit(X_train,y_train)
predkn=knn.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, predkn))
print('Confusion Matrix:',confusion_matrix(y_test, predkn))
print(classification_report(y_test,predkn))
# Out:
# Accuracy Score: 0.8411123532699832
# Confusion Matrix: [[5466 1706]
#  [ 568 6572]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83      7172
#            1       0.79      0.92      0.85      7140
#
#     accuracy                           0.84     14312
#    macro avg       0.85      0.84      0.84     14312
# weighted avg       0.85      0.84      0.84     14312

# %%
#Using Logistic Regression
LR=LogisticRegression()
LR.fit(X_train,y_train)
predlr=LR.predict(X_test)
print('Accuracy Score:',accuracy_score(y_test, predlr))
print('Confusion Matrix:',confusion_matrix(y_test, predlr))
print(classification_report(y_test,predlr))
# Out:
# Accuracy Score: 0.75
# Confusion Matrix: [[5227 1945]
#  [1633 5507]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.73      0.75      7172
#            1       0.74      0.77      0.75      7140
#
#     accuracy                           0.75     14312
#    macro avg       0.75      0.75      0.75     14312
# weighted avg       0.75      0.75      0.75     14312

# %% [markdown]
# # Cross Validation Score:

# %%
# cv score for Logistic Regression 
print(cross_val_score(LR,X,y,cv=5).mean())
# Out:
# 0.7484175752559127

# %%
# cv score for Decision Tree Classifier
print(cross_val_score(DTC,X,y,cv=5).mean())
# Out:
# 0.8302536322901322

# %%
# cv score for Random Forest Classifier
print(cross_val_score(RFC,X,y,cv=5).mean())
# Out:
# 0.8803310057833558

# %% [markdown]
# By looking at the above difference of model accuracy and cross validation score, we found Random Forest Classifier as the best model

# %% [markdown]
# # Hyper Parameter tuning

# %%
parameter = {'criterion':['gini','entropy'],
             'max_depth': [10,15,20,25],
             'n_estimators':[100,200,300,400],
             'max_features': ["auto","sqrt","log2"]}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameter,cv=5)

# %%
GCV.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [201], in <cell line: 1>()
# ----> 1 GCV.fit(X_train,y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in __call__(self, iterable)
#    1044     self._backend.start_call()
#    1045 iterator = iter(iterable)
# -> 1046 pre_dispatch = self.pre_dispatch
#    1048 if pre_dispatch == 'all' or n_jobs == 1:
#    1049     # prevent further dispatch via multiprocessing callback thread
#    1050     self._original_iterator = None
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in dispatch_one_batch(self, iterator)
#     852     batch_size = self.batch_size
#     854 with self._lock:
#     855     # to ensure an even distribution of the workolad between workers,
#     856     # we look ahead in the original iterators more than batch_size
#    (...)
#     859     # queue, _ready_batches, that is looked-up prior to re-consuming
#     860     # tasks from the origal iterator.
# --> 861     try:
#     862         tasks = self._ready_batches.get(block=False)
#     863     except queue.Empty:
#     864         # slice the iterator n_jobs * batchsize items at a time. If the
#     865         # slice returns less than that, then the current batchsize puts
#    (...)
#     868         # accordingly to distribute evenly the last items between all
#     869         # workers.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in _dispatch(self, batch)
#     775     n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
#     776                                      **self._backend_args)
#     777     if self.timeout is not None and not self._backend.supports_timeout:
#     778         warnings.warn(
# --> 779             'The backend class {!r} does not support timeout. '
#     780             "You have set 'timeout={}' in Parallel but "
#     781             "the 'timeout' parameter will not be used.".format(
#     782                 self._backend.__class__.__name__,
#     783                 self.timeout))
#     785 except FallbackToBackend as e:
#     786     # Recursively initialize the backend in case of requested fallback.
#     787     self._backend = e.backend
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in __init__(self, batch)
#     571 def terminate(self):
# --> 572     if self._workers is not None:
#     573         # Don't terminate the workers as we want to reuse them in later
#     574         # calls, but cleanup the temporary resources that the Parallel call
#     575         # created. This 'hack' requires a private, low-level operation.
#     576         self._workers._temp_folder_manager._unlink_temporary_resources(
#     577             context_id=self.parallel._id
#     578         )
#     579         self._workers = None
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in __call__(self)
#     256 # Under Linux or OS X the default start method of multiprocessing
#     257 # can cause third party libraries to crash. Under Python 3.4+ it is possible
#     258 # to set an environment variable to switch the default start method from
#     259 # 'fork' to 'forkserver' or 'spawn' to avoid this issue albeit at the cost
#     260 # of causing semantic changes and some additional pool instantiation overhead.
#     261 DEFAULT_MP_CONTEXT = None
# --> 262 if hasattr(mp, 'get_context'):
#     263     method = os.environ.get('JOBLIB_START_METHOD', '').strip() or None
#     264     if method is not None:
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     256 # Under Linux or OS X the default start method of multiprocessing
#     257 # can cause third party libraries to crash. Under Python 3.4+ it is possible
#     258 # to set an environment variable to switch the default start method from
#     259 # 'fork' to 'forkserver' or 'spawn' to avoid this issue albeit at the cost
#     260 # of causing semantic changes and some additional pool instantiation overhead.
#     261 DEFAULT_MP_CONTEXT = None
# --> 262 if hasattr(mp, 'get_context'):
#     263     method = os.environ.get('JOBLIB_START_METHOD', '').strip() or None
#     264     if method is not None:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:702, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     699 result["fit_error"] = None
#     701 fit_time = time.time() - start_time
# --> 702 test_scores = _score(estimator, X_test, y_test, scorer, error_score)
#     703 score_time = time.time() - start_time - fit_time
#     704 if return_train_score:
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:761, in _score(estimator, X_test, y_test, scorer, error_score)
#     759         scores = scorer(estimator, X_test)
#     760     else:
# --> 761         scores = scorer(estimator, X_test, y_test)
#     762 except Exception:
#     763     if error_score == "raise":
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py:418, in _passthrough_scorer(estimator, *args, **kwargs)
#     416 def _passthrough_scorer(estimator, *args, **kwargs):
#     417     """Function that wraps estimator.score"""
# --> 418     return estimator.score(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:651, in ClassifierMixin.score(self, X, y, sample_weight)
#     626 """
#     627 Return the mean accuracy on the given test data and labels.
#     628
#    (...)
#     647     Mean accuracy of ``self.predict(X)`` wrt. `y`.
#     648 """
#     649 from .metrics import accuracy_score
# --> 651 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:808, in ForestClassifier.predict(self, X)
#     787 def predict(self, X):
#     788     """
#     789     Predict class for X.
#     790
#    (...)
#     806         The predicted classes.
#     807     """
# --> 808     proba = self.predict_proba(X)
#     810     if self.n_outputs_ == 1:
#     811         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:861, in ForestClassifier.predict_proba(self, X)
#     856 all_proba = [
#     857     np.zeros((X.shape[0], j), dtype=np.float64)
#     858     for j in np.atleast_1d(self.n_classes_)
#     859 ]
#     860 lock = threading.Lock()
# --> 861 Parallel(
#     862     n_jobs=n_jobs,
#     863     verbose=self.verbose,
#     864     **_joblib_parallel_args(require="sharedmem"),
#     865 )(
#     866     delayed(_accumulate_prediction)(e.predict_proba, X, all_proba, lock)
#     867     for e in self.estimators_
#     868 )
#     870 for proba in all_proba:
#     871     proba /= len(self.estimators_)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in __call__(self, iterable)
#    1044     self._backend.start_call()
#    1045 iterator = iter(iterable)
# -> 1046 pre_dispatch = self.pre_dispatch
#    1048 if pre_dispatch == 'all' or n_jobs == 1:
#    1049     # prevent further dispatch via multiprocessing callback thread
#    1050     self._original_iterator = None
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in dispatch_one_batch(self, iterator)
#     852     batch_size = self.batch_size
#     854 with self._lock:
#     855     # to ensure an even distribution of the workolad between workers,
#     856     # we look ahead in the original iterators more than batch_size
#    (...)
#     859     # queue, _ready_batches, that is looked-up prior to re-consuming
#     860     # tasks from the origal iterator.
# --> 861     try:
#     862         tasks = self._ready_batches.get(block=False)
#     863     except queue.Empty:
#     864         # slice the iterator n_jobs * batchsize items at a time. If the
#     865         # slice returns less than that, then the current batchsize puts
#    (...)
#     868         # accordingly to distribute evenly the last items between all
#     869         # workers.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in _dispatch(self, batch)
#     775     n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
#     776                                      **self._backend_args)
#     777     if self.timeout is not None and not self._backend.supports_timeout:
#     778         warnings.warn(
# --> 779             'The backend class {!r} does not support timeout. '
#     780             "You have set 'timeout={}' in Parallel but "
#     781             "the 'timeout' parameter will not be used.".format(
#     782                 self._backend.__class__.__name__,
#     783                 self.timeout))
#     785 except FallbackToBackend as e:
#     786     # Recursively initialize the backend in case of requested fallback.
#     787     self._backend = e.backend
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in __init__(self, batch)
#     571 def terminate(self):
# --> 572     if self._workers is not None:
#     573         # Don't terminate the workers as we want to reuse them in later
#     574         # calls, but cleanup the temporary resources that the Parallel call
#     575         # created. This 'hack' requires a private, low-level operation.
#     576         self._workers._temp_folder_manager._unlink_temporary_resources(
#     577             context_id=self.parallel._id
#     578         )
#     579         self._workers = None
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in __call__(self)
#     256 # Under Linux or OS X the default start method of multiprocessing
#     257 # can cause third party libraries to crash. Under Python 3.4+ it is possible
#     258 # to set an environment variable to switch the default start method from
#     259 # 'fork' to 'forkserver' or 'spawn' to avoid this issue albeit at the cost
#     260 # of causing semantic changes and some additional pool instantiation overhead.
#     261 DEFAULT_MP_CONTEXT = None
# --> 262 if hasattr(mp, 'get_context'):
#     263     method = os.environ.get('JOBLIB_START_METHOD', '').strip() or None
#     264     if method is not None:
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     256 # Under Linux or OS X the default start method of multiprocessing
#     257 # can cause third party libraries to crash. Under Python 3.4+ it is possible
#     258 # to set an environment variable to switch the default start method from
#     259 # 'fork' to 'forkserver' or 'spawn' to avoid this issue albeit at the cost
#     260 # of causing semantic changes and some additional pool instantiation overhead.
#     261 DEFAULT_MP_CONTEXT = None
# --> 262 if hasattr(mp, 'get_context'):
#     263     method = os.environ.get('JOBLIB_START_METHOD', '').strip() or None
#     264     if method is not None:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:640, in _accumulate_prediction(predict, X, out, lock)
#     633 def _accumulate_prediction(predict, X, out, lock):
#     634     """
#     635     This is a utility function for joblib's Parallel.
#     636
#     637     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     638     complains that it cannot pickle it when placed there.
#     639     """
# --> 640     prediction = predict(X, check_input=False)
#     641     with lock:
#     642         if len(out) == 1:
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:978, in DecisionTreeClassifier.predict_proba(self, X, check_input)
#     976     normalizer = proba.sum(axis=1)[:, np.newaxis]
#     977     normalizer[normalizer == 0.0] = 1.0
# --> 978     proba /= normalizer
#     980     return proba
#     982 else:
#
# KeyboardInterrupt:

# %%
GCV.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [202], in <cell line: 1>()
# ----> 1 GCV.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
Final_mod=RandomForestClassifier(criterion='gini',max_depth=25, max_features='auto', n_estimators=200)
Final_mod.fit(X_train,y_train)
pred=Final_mod.predict(X_test)
acc=accuracy_score(y_test, pred)

print(acc*100)
# Out:
# 88.31749580771381

# %% [markdown]
# # ROC-AUC curve

# %%
# Plotting for all the models used here
from sklearn import datasets 
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import plot_roc_curve 
disp = plot_roc_curve(RFC,X_test,y_test)
plot_roc_curve(knn, X_test, y_test, ax=disp.ax_)     # ax_=Axes with confusion matrix
plot_roc_curve(SV, X_test, y_test, ax=disp.ax_)
plot_roc_curve(LR, X_test, y_test, ax=disp.ax_)
plot_roc_curve(DTC, X_test, y_test, ax=disp.ax_)


plt.legend(prop={'size':11}, loc='lower right')
plt.show()

# %% [markdown]
# # Saving the mode

# %%
import joblib
joblib.dump(Final_mod,"Censusincome.pkl")
# Out:
# ['Censusincome.pkl']
